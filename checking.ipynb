# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("outputs/master/master_std_1_tp_2_sl_5.csv")
df
# Out:
#      index             Datetime     Open     High      Low    Close  \
# 0        0  2022-05-26 06:00:00  4000.25  4001.25  3999.25  4001.25
# 1        1  2022-05-26 06:01:00  4001.00  4001.25  4000.25  4000.75
# 2        2  2022-05-26 06:02:00  4000.75  4001.25  3998.25  3999.00
# 3        3  2022-05-26 06:03:00  3999.00  4000.00  3998.00  3999.25
# 4        4  2022-05-26 06:04:00  3999.00  3999.25  3997.00  3997.25
# ..     ...                  ...      ...      ...      ...      ...
# 929     26  2022-05-27 13:26:00  4162.25  4163.00  4162.00  4163.00
# 930     27  2022-05-27 13:27:00  4163.00  4163.25  4162.25  4163.25
# 931     28  2022-05-27 13:28:00  4163.25  4164.75  4163.00  4163.50
# 932     29  2022-05-27 13:29:00  4163.50  4165.75  4163.50  4165.25
# 933     30  2022-05-27 13:30:00  4165.00  4165.50  4165.00  4165.50
#
#          cont_up    cont_down       hl2      lin_reg     1_std_up   1_std_down
# ...

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])

# %%
df2 = df.copy()
df = df[df['Datetime'].dt.date <= datetime.date(2022, 5, 26)]

# %%
df[(df['Datetime'].dt.time >= datetime.time(7, 20)) & (df['Datetime'].dt.time <= datetime.time(8,0))].set_index("Datetime")[['High','Low','cont_up','cont_down']].plot(figsize=(20,20))
plt.grid(which="both")
