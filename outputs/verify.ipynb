# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import datetime

import warnings
warnings.simplefilter("ignore")

# %%
master = pd.read_excel("master/estest_master_std_3_tp_2_sl_4.xlsx")

# %%
master.drop(columns=['index'], inplace=True)

# %%
master['Datetime'] = pd.to_datetime(master['Datetime'])

# %%
master.tail(5)
# Out:
#                Datetime     Open     High      Low    Close      cont_up  \
# 743 2022-05-27 12:11:00  4141.25  4142.75  4140.75  4141.25  4149.589375
# 744 2022-05-27 12:12:00  4141.50  4142.75  4141.00  4142.25  4149.858388
# 745 2022-05-27 12:13:00  4142.00  4143.00  4142.00  4142.75  4150.113352
# 746 2022-05-27 12:14:00  4143.00  4143.00  4141.75  4142.75  4150.348406
# 747 2022-05-27 12:15:00  4142.75  4142.75  4142.75  4142.75  4150.459375
#
#        cont_down       hl2      lin_reg     1_std_up   1_std_down
# 743  4133.089375  4141.750  4141.994669  4158.119669  4125.869669
# 744  4133.358388  4141.875  4142.622610  4158.747610  4126.497610
# 745  4133.613352  4142.500  4143.250551  4159.375551  4127.125551
# 746  4133.848406  4142.375  4143.878493  4160.003493  4127.753493
# 747  4133.959375  4142.750  4144.506434  4160.631434  4128.381434

# %%
master.iloc[500:700][['High','Low','lin_reg','cont_up','cont_down','lin_reg']].plot(figsize=(30, 30))
# Out:
# <AxesSubplot:>
